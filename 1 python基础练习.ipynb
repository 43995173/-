# %% [markdown]
# # Python 基础练习（在有问号‘？’的地方补充程序）
# ## 2019.9  V1  郑博

# %% [markdown]
# ## 1 输入输出
# 使用input分别输入一个字符串和数字给str和num，查看str和num的类型并使用print输出，输出格式如下：str的类型为...，num的类型为...(type(),formate())。结果如下图：
# ![image.png](attachment:image.png)

# %%
s1 = ？
num = ？
# 使用print和format输出s1的类型为...,num的类型为....
？？？
# Out:
# 请输入字符串：fg
# 请输入数字：4556
# s1的类型为<class 'str'>，num的类型为<class 'str'>

# %% [markdown]
# ## 2 序列
# ### 2.1 列表和字典
# 创建列表：创建一个长度为5的列表list1，list1如下图：【列表元素按顺序包含整型数，浮点数，字符串，列表（长度为3），字典（3个键和值）】，使用print输出列表及其类型
# ![image.png](attachment:image.png)

# %%
# 创建列表list1
list1 = ？
# 输出list1和它的类型
？？？
# Out:
# [78, 4.23, 'python', [5, '你好', 'world'], {'a': '第一个值', 'b': '第二个值', 'c': '第三个值'}]
# <class 'list'>

# %% [markdown]
# ### 使用函数创建列表及合并等
# 1 创建一个空列表list2，使用for循环为空列表赋值1,2,3,4,5。【range()函数，append()函数】<br>
# 2 使用for循环创建一个1到10（不包括10）之间所有偶数的数值列表list3。【range()函数，append()】<br>
# 3 将list1、list2和list3合并为一个列表list，计算list的长度，查找4在list中出现的次数，返回第一个2出现的下标【+，len()，count()，index()】

# %%
# 创建空列表list2，并用for循环为其赋值
list2 = ？
？？？
# 输出list2
？？？

#创建list3并赋值
？？？

# 创建list
list = ？
# 计算list长度并输出
？？？
# 查找4在list中出现次数并输出
？？？
# 输出第一个2出现的下标
？？？
# Out:
# [1, 2, 3, 4, 5]
# [2, 4, 6, 8]
# [78, 4.23, 'python', [5, '你好', 'world'], {'a': '第一个值', 'b': '第二个值', 'c': '第三个值'}, 1, 2, 3, 4, 5, 2, 4, 6, 8]
# 14
# 2
# 6

# %% [markdown]
# ### 字典创建，修改
# 1 创建字典dict1和dict2，包含4个元素，键为4个人名，dict1的值为对应的语文分数，dict2的值为对应的数学分数（具体如图所示）【请用两种方法：直接创建；dict和zip()函数通过列表创建】<br>
# 2 用dict1代替list中的字典，并将dict2插入到list中dict1的后面【insert()】<br>
# dict1如图：![image.png](attachment:image.png)
# dict2如图：![image.png](attachment:image.png)

# %%
# 创建dict1
dict1 = ？
# 使用zip()函数创建dict2
list11 = ['赵一', '钱二', '孙三', '李四']
list12 = ['82', '78', '75', '90']
dict2 = ？
print(dict1)
print(dict2)

# 将list中的字典换为dict1，输出list
？？？
# 使用insert()函数将dict2插入到list中dict1的后面
？？？
print(list)
# Out:
# {'赵一': '85', '钱二': '90', '孙三': '70', '李四': '80'}
# {'赵一': '82', '钱二': '78', '孙三': '75', '李四': '90'}
# [78, 4.23, 'python', [5, '你好', 'world'], {'赵一': '85', '钱二': '90', '孙三': '70', '李四': '80'}, {'赵一': '82', '钱二': '78', '孙三': '75', '李四': '90'}, 1, 2, 3, 4, 5, 2, 4, 6, 8]

# %% [markdown]
# ### 字典索引
# 1 索引字典dict1中钱二的分数，使用get()索引字典dict2中孙三的分数。<br>
# 2 索引dict1中王五的分数，如果不存在此人，则输出“此人不存在”。【if】<br>
# 3 在dict1中添加王五的分数88，修改赵一的分数为92，并删除周六的分数（如果删除时元素不存在，则会出现异常，所以请先判断要删除的元素是否存在），如果周六不存在，则添加周六的分数为87。

# %%
# 输出dict1中钱二的分数
？？？
# 使用get()函数输出dict2中孙三的分数
？？？

# 输出dict1中王五的分数
？？？

# 在dict1中添加王五的分数为88
？？？
print(list)
print(dict1)
# 修改dict1中赵一的分数为92
？？？
print(dict1)

# 删除周六的分数，需先判断是否存在，若周六不存在，添加周六分数为87
？？？
print(dict1)

print(list)#注意：多次运行结果会不同，list已经是替换好的
# Out:
# 90
# 90
# 此人不存在
# 王五的语文分数是： 此人不存在
# [78, 4.23, 'python', [5, '你好', 'world'], {'赵一': '85', '钱二': '90', '孙三': '70', '李四': '80', '王五': '88'}, {'赵一': '82', '钱二': '78', '孙三': '75', '李四': '90'}, 1, 2, 3, 4, 5, 2, 4, 6, 8]
# {'赵一': '85', '钱二': '90', '孙三': '70', '李四': '80', '王五': '88'}
# {'赵一': '92', '钱二': '90', '孙三': '70', '李四': '80', '王五': '88'}
# {'赵一': '92', '钱二': '90', '孙三': '70', '李四': '80', '王五': '88', '周六': '87'}
# [78, 4.23, 'python', [5, '你好', 'world'], {'赵一': '92', '钱二': '90', '孙三': '70', '李四': '80', '王五': '88', '周六': '87'}, {'赵一': '82', '钱二': '78', '孙三': '75', '李四': '90'}, 1, 2, 3, 4, 5, 2, 4, 6, 8]

# %% [markdown]
# ### 列表索引
# 1 此时list中的dict1已经由新的dict1替代，索引list中列表的第二个值，索引list中第一个字典的第3个值。<br>
# 2 索引list中前3个值，最后3个值以及第2-5个值（包括第2和第5个值）使用“：”<br>
# 3 将list进行反向，再次做2的操作【reversed()】<br>
# 4 再次将list进行反向，获取list中第1,3,5个元素放到list4中，将list4中元素重复3遍放入list5中

# %%
#list.reverse()
# 输出list中的第二个值，输出list中第一个字典的第3个值
？？？

# 输出list中前3个值，最后3个值以及第2-5个值（包括第2和第5个值）使用“：”
？？？

# 将list进行反向，再次做步骤2的操作【reversed()】
？？？

# 再次将list进行反向 
？？？
print(list)
# 获取list中第1,3,5个元素放到list4中，将list4中元素重复3遍放入list5中
list4 = ？
print(list4)
list5 = ？
print(list5)
# Out:
# 4.23
# 你好
# 70
# [78, 4.23, 'python']
# [4, 6, 8]
# [4.23, 'python', [5, '你好', 'world'], {'赵一': '92', '钱二': '90', '孙三': '70', '李四': '80', '王五': '88', '周六': '87'}, {'赵一': '82', '钱二': '78', '孙三': '75', '李四': '90'}]
# [8, 6, 4, 2, 5, 4, 3, 2, 1, {'赵一': '82', '钱二': '78', '孙三': '75', '李四': '90'}, {'赵一': '92', '钱二': '90', '孙三': '70', '李四': '80', '王五': '88', '周六': '87'}, [5, '你好', 'world'], 'python', 4.23, 78]
# [8, 6, 4]
# ['python', 4.23, 78]
# [6, 4, 2, 5, 4]
# [78, 4.23, 'python', [5, '你好', 'world'], {'赵一': '92', '钱二': '90', '孙三': '70', '李四': '80', '王五': '88', '周六': '87'}, {'赵一': '82', '钱二': '78', '孙三': '75', '李四': '90'}, 1, 2, 3, 4, 5, 2, 4, 6, 8]
# [78, 'python', {'赵一': '92', '钱二': '90', '孙三': '70', '李四': '80', '王五': '88', '周六': '87'}]
# ...

# %% [markdown]
# ### 数值列表计算与排序
# 1 将list2和list3合并为list4<br>
# 2 将list4转换为字符串，存储到s4中<br>
# 3 计算list4的长度，求list4中最大值，最小值，和及平均值。<br>
# 4 使用sorted()对list4进行排序<br>
# 5 将list4赋值给list5和list6，使用sort()对list5进行升序排列，对list6进行降序排列。<br>
# 【注意，sorted()排序后原列表顺序不变，sort()排序后原列表顺序改变】<br>
# https://www.cnblogs.com/who-care/p/9306800.html【列表，字典，字符串转换】

# %%
# 将list2和list3合并为list4
list4 = ？
print(list4)
type(list4)

# 将list4转换为字符串，存储到s4中
s4 = ？
print(s4)
type(s4)

#计算并输出list4的长度，求list4中最大值，最小值，和及平均值。
？？？

# 使用sorted()对list4进行排序
？？？
print(list4)

# 将list4赋值给list5和list6，使用sort()对list5进行升序排列，对list6进行降序排列。
list5 = list4
list6 = list4
？？？
print(list5)
？？？
print(list6)
# Out:
# [1, 2, 3, 4, 5, 2, 4, 6, 8]
# [1, 2, 3, 4, 5, 2, 4, 6, 8]
# 9
# 35
# 8
# 1
# 3.888888888888889
# 升序： [1, 2, 2, 3, 4, 4, 5, 6, 8]
# [1, 2, 3, 4, 5, 2, 4, 6, 8]
# [1, 2, 2, 3, 4, 4, 5, 6, 8]
# [8, 6, 5, 4, 4, 3, 2, 2, 1]

# %% [markdown]
# ### 遍历列表
# 1 使用for循环遍历列表list，输出元素的值。<br>
# 2 使用for循环和enumerate()同时输出索引值和元素内容。

# %%
# 使用for循环遍历列表list，输出元素的值。
？？？

# 使用for循环和enumerate()同时输出索引值和元素内容。
？？？
# Out:
# 78
# 4.23
# python
# [5, '你好', 'world']
# {'赵一': '92', '钱二': '90', '孙三': '70', '李四': '80', '王五': '88', '周六': '87'}
# {'赵一': '82', '钱二': '78', '孙三': '75', '李四': '90'}
# 1
# 2
# 3
# 4
# 5
# 2
# 4
# 6
# 8
# 1 78
# 2 4.23
# 3 python
# 4 [5, '你好', 'world']
# 5 {'赵一': '92', '钱二': '90', '孙三': '70', '李四': '80', '王五': '88', '周六': '87'}
# 6 {'赵一': '82', '钱二': '78', '孙三': '75', '李四': '90'}
# 7 1
# 8 2
# 9 3
# 10 4
# 11 5
# 12 2
# 13 4
# 14 6
# 15 8

# %% [markdown]
# ### 遍历字典
# 1 遍历字典dict1中的全部键-值对，并输出遍历后得到的元素的类型。【item()】<br>
# 2 返回字典dict1的值和键【values(), keys()】<br>
# 3 获取字典dict1中具体的每个键和值。【item()】输出类似“赵一的语文分数为：92”等等。

# %%
# 遍历字典dict1中的全部键-值对，并输出遍历后得到的元素的类型。【item()】
？？？

# 遍历并输出字典dict1的值和键【values(), keys()】
？？？


？？？

# 获取字典dict1中具体的每个键和值。【item()】输出类似“赵一的语文分数为：92”等等。
？？？
# Out:
# ('赵一', '92')
# ('钱二', '90')
# ('孙三', '70')
# ('李四', '80')
# ('王五', '88')
# ('周六', '87')
# <class 'tuple'>
# 赵一
# 钱二
# 孙三
# 李四
# 王五
# 周六
# <class 'str'>
# 92
# 90
# 70
# 80
# 88
# 87
# <class 'str'>
# 赵一 的语文分数为： 92
# 钱二 的语文分数为： 90
# 孙三 的语文分数为： 70
# 李四 的语文分数为： 80
# 王五 的语文分数为： 88
# 周六 的语文分数为： 87

# %% [markdown]
# ## 2.2 字符串
# 创建一个字符串string1 =  1a2b'3c 4d/5e;6F 人们7g 。创建一个字符串string2 = h.ij:klM+n2a=1b?3c 4d

# %%
# 创建字符串string1 和string2
string1 = ？
print(string1)
string2 = ？
print(string2)
# Out:
#  1a2b'3c 4d/5e;6F 人们7g
# h.ij:klM+n2a=1b?3c 4d

# %% [markdown]
# ### 字符串拼接、计算长度、截取
# 1 将string1和string2用“-”进行拼接，得到字符串string。<br>
# 2 分别计算string1，string2和string的长度。<br>
# 3 截取string的前3个字符给substr1，截取最后一个字符给substr2 ，截取字符串中的两个“3c 4d”并用“+”拼接给substr3

# %%
# 将string1和string2用“-”进行拼接，得到字符串string。
string = ？
print(string)

# 分别计算并输出string1，string2和string的长度。
？？？

# 截取string的前3个字符给substr1，截取最后一个字符给substr2 ，截取字符串中的两个“3c 4d”并用“+”拼接给substr3
substr1 = ？
substr2 = ？
substr3 = ？
print(substr1)
print(substr2)
print(substr3)
# Out:
#  1a2b'3c 4d/5e;6F 人们7g -h.ij:klM+n2a=1b?3c 4d
# 23 22 46
#  1a
#
# '3c 4+c 4d

# %% [markdown]
# ### 查找字符串【string中字符不能变化】
# 1 字符串string中是否存在英文字母【isalpha()，正则表达式】<br>
# 2 字符串string中是否存在大写字母，如存在，将大写字母转换为小写字母，存入string_low中。【正则表达式，lower()】<br>
# 3 字符串string中是否存在小写字母，如存在，将小写字母转换为大写字母，存入string_up中。【正则表达式，upper()】<br>
# 4 字符串string中是否存在数字，如存在，将数字输出到列表list_str_num中。【isdigit()】<br>
# 5 字符串string是否存在空格，如存在，根据空格将string拆分，存入list_space中，将string中空格删除存入string_no中。【split()，split('')】【strip()】<br>
# 6 采用空格、“.”、“?”这三个字符对string进行分割，存入list_three中。【re.split()】<br>
# 7 查找字符串string中是否存在中文，如存在，将其替换为X，结果存入result。【re.sub()】

# %%
import re
# 字符串string中是否存在英文字母【isalpha()，正则表达式】
？？？
    
# 字符串string中是否存在大写字母，如存在，将大写字母转换为小写字母，存入string_low中。【正则表达式，lower()】    
？？？
    
print(string)

# 字符串string中是否存在小写字母，如存在，将小写字母转换为大写字母，存入string_up中。【正则表达式，upper()】
？？？

# 字符串string中是否存在数字，如存在，将数字输出到列表list_str_num中。【isdigit()】
list_str_num = []
？？？
print(type(list_str_num))

# 字符串string是否存在空格，如存在，根据空格将string拆分，存入list_space中，将string中空格删除存入string_no中。【split()，split('')】【strip()】
？？？
print(string)
type(list_space)
print(string_no)
type(string_no)

# 采用空格、“.”、“?”这三个字符对string进行分割，存入list_three中。【re.split()】
list_three = ？
print(list_three)

# 查找字符串string中是否存在中文，如存在，将其替换为X，结果存入result。【re.sub()】
result = ？
print(result)
# Out:
# 有英文
# True
# 含有英文字符
#  1a2b'3c 4d/5e;6f 人们7g -h.ij:klm+n2a=1b?3c 4d
#  1a2b'3c 4d/5e;6F 人们7g -h.ij:klM+n2a=1b?3c 4d
#  1A2B'3C 4D/5E;6F 人们7G -H.IJ:KLM+N2A=1B?3C 4D
#  1A2B'3C 4D/5E;6F 人们7G -H.IJ:KLM+N2A=1B?3C 4D
# ['1', '2', '3', '4', '5', '6', '7', '2', '1', '3', '4']
# ["1a2b'3c", '4d/5e;6F', '人们7g', '-h.ij:klM+n2a=1b?3c', '4d']
#  1a2b'3c 4d/5e;6F 人们7g -h.ij:klM+n2a=1b?3c 4d
# 1a2b'3c4d/5e;6F人们7g-h.ij:klM+n2a=1b?3c4d
# ['', "1a2b'3c", '4d/5e;6F', '人们7g', '-h', 'ij:klM+n2a=1b', '3c', '4d', '']
#  1a2b'3c 4d/5e;6F XX7g -h.ij:klM+n2a=1b?3c 4d

# %% [markdown]
# ## 3 小混战？

# %% [markdown]
# ### 1）写代码,有如下变量,请按照要求实现每个功能
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 2）有列表data=['albert',18,[2000,1,1]]，分别取出列表中的名字，年龄，出生的年，月，日赋值给不同的变量。

# %% [markdown]
# ### 3）有如下值集合 [11,22,33,44,55,66,77,88,99,90]，将所有大于 66 的值保存至字典的第一个key中，将小于 66 的值保存至第二个key的值中，即： {'k1': 大于66的所有值, 'k2': 小于66的所有值}

# %% [markdown]
# ### 4）使用至少两种方法统计字符串 s='hello albert albert say hello world world'中每个单词的个数，结果如：
# ![image.png](attachment:image.png)

# %% [markdown]
# ### 5）实现简易购物程序,要求如下：首先打印商品详细信息，然后请用户输入商品名和购买个数，则将商品名，价格，购买个数加入购物列表，如果输入为空或其他非法输入则要求用户重新输入
# ![image.png](attachment:image.png)
